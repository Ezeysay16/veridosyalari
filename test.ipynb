# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("/Users/esmazeynep/Desktop/kcl-artificial-intelligence-competition-22-23/train_set.csv")
train.head()
# Out:
#      id                 name           artist  danceability  energy  key  \
# 0  1000            Breakeven       The Script         0.630   0.694   10
# 1  1001         Why Suffer??     Carlos Truly         0.593   0.458    0
# 2  1002   Out Here On My Own  Various Artists         0.411   0.129    7
# 3  1003  home (feat. Kehina)             ones         0.771   0.361    0
# 4  1004       Way down We Go            KALEO         0.489   0.505   10
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -4.501     1       0.0242         0.144          0.000000    0.0835
# 1    -9.108     1       0.0774         0.495          0.059500    0.0878
# 2   -15.070     1       0.0358         0.980          0.000025    0.0850
# 3   -15.171     0       0.0517         0.670          0.826000    0.1080
# 4    -8.022     0       0.1170         0.579          0.000333    0.1040
#
#    valence    tempo  duration_ms  time_signature  realease_year emotion_tag
# ...

# %%
test_no_labels = pd.read_csv("/Users/esmazeynep/Desktop/kcl-artificial-intelligence-competition-22-23/test_set_no_labels.csv")
test_no_labels.head()
# Out:
#    id                           name             artist  danceability  energy  \
# 0   1                         My Way        Limp Bizkit         0.576   0.864
# 1   2  Symphony (feat. Zara Larsson)       Clean Bandit         0.715   0.605
# 2   3             concert for aliens  Machine Gun Kelly         0.507   0.951
# 3   4                       Everlong       Foo Fighters         0.413   0.881
# 4   5                    WITHOUT YOU      The Kid LAROI         0.662   0.413
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    6    -3.981     1       0.0462       0.02000          0.000002    0.6830
# 1    0    -5.128     0       0.0428       0.23900          0.000014    0.1890
# 2   11    -2.999     1       0.0586       0.00032          0.000000    0.3300
# 3   11    -5.541     0       0.0367       0.00006          0.000308    0.0805
# 4    0    -7.357     1       0.0299       0.21300          0.000000    0.1340
#
# ...

# %%
val_set = pd.read_csv("/Users/esmazeynep/Desktop/kcl-artificial-intelligence-competition-22-23/val_set.csv")
val_set.head()
# Out:
#      id                             name         artist  danceability  energy  \
# 0  3000                    Thunderstruck          AC/DC         0.495   0.892
# 1  3001  I'm Trynna Tell U That I Love U        Artemas         0.819   0.889
# 2  3002                       Take A Bow        Rihanna         0.708   0.470
# 3  3003         Money Rain - Phonk Remix        VTORNIK         0.936   0.791
# 4  3004                  Love Proceeding  BADBADNOTGOOD         0.318   0.569
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    4    -5.601     1       0.0349      0.000128          0.021600    0.2070
# 1   10    -2.473     1       0.0558      0.325000          0.000336    0.2250
# 2    9    -7.590     1       0.0659      0.248000          0.000000    0.0852
# 3    6    -3.605     1       0.2350      0.355000          0.006280    0.1680
# 4    8   -10.453     0       0.0355      0.077000          0.926000    0.0854
#
# ...

# %%
data = pd.concat([train, test_no_labels])

# %%
data = pd.concat([data, val_set])

# %%
data
# Out:
#        id                 name           artist  danceability  energy  key  \
# 0    1000            Breakeven       The Script         0.630   0.694   10
# 1    1001         Why Suffer??     Carlos Truly         0.593   0.458    0
# 2    1002   Out Here On My Own  Various Artists         0.411   0.129    7
# 3    1003  home (feat. Kehina)             ones         0.771   0.361    0
# 4    1004       Way down We Go            KALEO         0.489   0.505   10
# ..    ...                  ...              ...           ...     ...  ...
# 595  3595            JoJo Pose     Apollo Fresh         0.781   0.533    1
# 596  3596               Sinner    Drowning Pool         0.549   0.949    4
# 597  3597        Under the Sun        R U Steve         0.766   0.187    1
# 598  3598          Coming Home         Sheppard         0.612   0.937    4
# 599  3599            Bad Bitch            Cappa         0.323   0.433    4
#
# ...

# %%
labelled = data[data["emotion_tag"].notnull()]
labelled
# Out:
#        id                   name             artist  danceability  energy  \
# 0    1000              Breakeven         The Script         0.630   0.694
# 8    1008           Stressed Out  Twenty One Pilots         0.734   0.637
# 12   1012  The One That Got Away         Katy Perry         0.687   0.792
# 18   1018      Armed & Dangerous           King Von         0.696   0.592
# 19   1019               Recovery      Justin Bieber         0.509   0.522
# ..    ...                    ...                ...           ...     ...
# 595  3595              JoJo Pose       Apollo Fresh         0.781   0.533
# 596  3596                 Sinner      Drowning Pool         0.549   0.949
# 597  3597          Under the Sun          R U Steve         0.766   0.187
# 598  3598            Coming Home           Sheppard         0.612   0.937
# 599  3599              Bad Bitch              Cappa         0.323   0.433
#
#      key  loudness  mode  speechiness  acousticness  instrumentalness  \
# ...

# %%
labelled.reset_index(drop = True, inplace = True)

# %%
labelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1160 non-null   int64
#  1   name              1160 non-null   object
#  2   artist            1160 non-null   object
#  3   danceability      1160 non-null   float64
#  4   energy            1160 non-null   float64
#  5   key               1160 non-null   int64
#  6   loudness          1160 non-null   float64
#  7   mode              1160 non-null   int64
#  8   speechiness       1160 non-null   float64
#  9   acousticness      1160 non-null   float64
#  10  instrumentalness  1160 non-null   float64
#  11  liveness          1160 non-null   float64
#  12  valence           1160 non-null   float64
#  13  tempo             1160 non-null   float64
#  14  duration_ms       1160 non-null   int64
#  15  time_signature    1160 non-null   int64
# ...

# %%
unlabelled = data[data["emotion_tag"].isnull()]
unlabelled
# Out:
#        id                 name           artist  danceability  energy  key  \
# 1    1001         Why Suffer??     Carlos Truly         0.593   0.458    0
# 2    1002   Out Here On My Own  Various Artists         0.411   0.129    7
# 3    1003  home (feat. Kehina)             ones         0.771   0.361    0
# 4    1004       Way down We Go            KALEO         0.489   0.505   10
# 5    1005    something special             joan         0.769   0.718    9
# ..    ...                  ...              ...           ...     ...  ...
# 595   596             In Bloom          Nirvana         0.436   0.876   10
# 596   597            Unsainted         Slipknot         0.427   0.946    7
# 597   598        I'll Be There            ConKi         0.726   0.872    5
# 598   599              Noticed        Lil Mosey         0.699   0.558   11
# 599   600                Spit.     WARGASM (UK)         0.511   0.728    1
#
# ...

# %%
unlabelled.reset_index(drop = True, inplace = True)
unlabelled
# Out:
#         id                 name           artist  danceability  energy  key  \
# 0     1001         Why Suffer??     Carlos Truly         0.593   0.458    0
# 1     1002   Out Here On My Own  Various Artists         0.411   0.129    7
# 2     1003  home (feat. Kehina)             ones         0.771   0.361    0
# 3     1004       Way down We Go            KALEO         0.489   0.505   10
# 4     1005    something special             joan         0.769   0.718    9
# ...    ...                  ...              ...           ...     ...  ...
# 2835   596             In Bloom          Nirvana         0.436   0.876   10
# 2836   597            Unsainted         Slipknot         0.427   0.946    7
# 2837   598        I'll Be There            ConKi         0.726   0.872    5
# 2838   599              Noticed        Lil Mosey         0.699   0.558   11
# 2839   600                Spit.     WARGASM (UK)         0.511   0.728    1
#
# ...

# %%
unlabelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2840 entries, 0 to 2839
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2840 non-null   int64
#  1   name              2840 non-null   object
#  2   artist            2840 non-null   object
#  3   danceability      2840 non-null   float64
#  4   energy            2840 non-null   float64
#  5   key               2840 non-null   int64
#  6   loudness          2840 non-null   float64
#  7   mode              2840 non-null   int64
#  8   speechiness       2840 non-null   float64
#  9   acousticness      2840 non-null   float64
#  10  instrumentalness  2840 non-null   float64
#  11  liveness          2840 non-null   float64
#  12  valence           2840 non-null   float64
#  13  tempo             2840 non-null   float64
#  14  duration_ms       2840 non-null   int64
#  15  time_signature    2840 non-null   int64
# ...

# %%
import seaborn as sns
sns.heatmap(labelled.corr())
# Out:
# <AxesSubplot:>
